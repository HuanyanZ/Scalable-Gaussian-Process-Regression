# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/changi_2024.csv")
df.head()
# Out:
# C:\Users\Sarakio\AppData\Local\Temp\ipykernel_12424\1534342504.py:1: DtypeWarning: Columns (18,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/changi_2024.csv")
#        STATION                 DATE  SOURCE  LATITUDE   LONGITUDE  ELEVATION  \
# 0  48698099999  2023-01-01T00:00:00       4  1.350189  103.994433        6.7
# 1  48698099999  2023-01-01T00:00:00       4  1.350189  103.994433        6.7
# 2  48698099999  2023-01-01T00:30:00       4  1.350189  103.994433        6.7
# 3  48698099999  2023-01-01T01:00:00       4  1.350189  103.994433        6.7
# 4  48698099999  2023-01-01T01:00:00       4  1.350189  103.994433        6.7
#
#                                  NAME REPORT_TYPE  CALL_SIGN QUALITY_CONTROL  \
# 0  SINGAPORE CHANGI INTERNATIONAL, SN       FM-12      99999            V020
# 1  SINGAPORE CHANGI INTERNATIONAL, SN       FM-15      99999            V020
# ...

# %%
to_drop = ["STATION", "QUALITY_CONTROL", "SOURCE", "LATITUDE", "LONGITUDE", "ELEVATION", "NAME", "REPORT_TYPE", "CALL_SIGN", "REM", "EQD"]

# %%
df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#                   DATE QUALITY_CONTROL             WND          CIG  \
# 0  2023-01-01T00:00:00            V020  070,1,N,0021,1  04500,1,9,9
# 1  2023-01-01T00:00:00            V020  330,1,V,0015,1  01829,1,C,N
# 2  2023-01-01T00:30:00            V020  999,9,V,0010,1  02134,1,C,N
# 3  2023-01-01T01:00:00            V020  040,1,N,0015,1  99999,9,9,9
# 4  2023-01-01T01:00:00            V020  330,1,N,0021,1  02134,1,C,N
#
#             VIS      TMP      DEW      SLP          AA1  AA2  ...  \
# 0  012000,1,9,9  +0257,1  +0228,1  10134,1  24,9999,9,9  NaN  ...
# 1  009999,1,9,9  +0260,1  +0230,1  99999,9          NaN  NaN  ...
# 2  009000,1,9,9  +0260,1  +0230,1  99999,9          NaN  NaN  ...
# 3  999999,9,9,9  +0261,1  +0228,1  10142,1  99,9999,9,9  NaN  ...
# 4  009999,1,9,9  +0260,1  +0230,1  99999,9          NaN  NaN  ...
#
#                   GA3  GA4                     GE1  \
# 0  05,1,+04500,1,03,1  NaN  9,AGL   ,+99999,+99999
# 1  07,1,+04572,1,99,9  NaN  9,AGL   ,+99999,+99999
# ...
